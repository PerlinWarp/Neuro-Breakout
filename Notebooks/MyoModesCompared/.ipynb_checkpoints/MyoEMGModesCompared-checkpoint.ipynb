# %% [markdown]
# # Myo modes comparison.
#
# The Myo has 3 different modes of EEG sending EEG data:
# ![MyoEMGModes.png](attachment:MyoEMGModes.png)
#
# I have recorded 20 seconds of hand waving to see the difference between these modes.
#
# Modes 1 and 2 were recorded shortly after one another, where as mode 3 was discovered later.
# To keep the positioning similar for all 3 recordings, the position of the main sensor pad with the LED pad was drawn with pen on my hand and subsequent recordings were aligned to this positioning.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
cols = ['One', 'Two', 'Three', "Four", "Five", "Six", "Seven", "Eight", "Rect", "Time_ns"]

df_f = pd.read_csv("20_0x01_filtered.csv")
df_f.columns = cols
df_f['Rect'] = df_f['Rect'] / max(df_f['Rect'])

df_n = pd.read_csv("NonFiltered.csv")
df_n.columns = ['One', 'Two', 'Three', "Four", "Five", "Six", "Seven", "Eight", "Rect"]
df_n['Rect'] = df_n['Rect'] / max(df_n['Rect'])


#df.to_csv("testing_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-911cf851bdec> in <module>
#       1 df_f = pd.read_csv("20_0x01_filtered.csv")
# ----> 2 df_f.columns = ['One', 'Two', 'Three', "Four", "Five", "Six", "Seven", "Eight", "Rect"]
#       3 df_f['Rect'] = df_f['Rect'] / max(df_f['Rect'])
#       4
#       5 df_n = pd.read_csv("NonFiltered.csv")
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     668     def _set_axis(self, axis: int, labels: Index) -> None:
#     669         labels = ensure_index(labels)
# --> 670         self._mgr.set_axis(axis, labels)
#     671         self._clear_item_cache()
#     672
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     218
#     219         if new_len != old_len:
# --> 220             raise ValueError(
#     221                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     222                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 10 elements, new values have 9 elements

# %%
df_f.plot()

# %%
df_n.plot()

# %% [markdown]
# We can see that the filtered data has been rectified and has a minimum of 20.

# %%
df_f.describe()
# Out:
#                One          Two        Three         Four         Five  \
# count  1398.000000  1398.000000  1398.000000  1398.000000  1398.000000
# mean     29.904864    38.164521    70.153076    39.292561    42.287554
# std       8.123966     7.175784    23.613586     8.445172    18.070656
# min      20.000000    26.000000    31.000000    24.000000    25.000000
# 25%      27.000000    34.000000    53.000000    34.000000    37.000000
# 50%      29.000000    37.000000    67.000000    37.000000    40.000000
# 75%      32.000000    41.000000    82.000000    43.000000    44.000000
# max     126.000000   116.000000   214.000000    97.000000   275.000000
#
#                Six        Seven        Eight         Rect
# count  1398.000000  1398.000000  1398.000000  1398.000000
# mean     41.766810    41.842632    32.167382     0.510040
# std       6.625042     8.179158     5.865764     0.289165
# min      26.000000    25.000000    21.000000     0.000000
# 25%      37.000000    36.000000    28.000000     0.257143
# 50%      41.000000    40.000000    32.000000     0.521429
# 75%      45.000000    46.000000    35.000000     0.757143
# max      79.000000    73.000000    94.000000     1.000000

# %%
df_n.describe()
# Out:
#                 One           Two         Three          Four          Five  \
# count  11889.000000  11889.000000  11889.000000  11889.000000  11889.000000
# mean      -0.759946     -0.854656     -0.420809     -0.784338     -0.887543
# std        5.275206     14.467316     31.617158     10.974287      4.101614
# min      -52.000000    -96.000000   -128.000000   -106.000000    -38.000000
# 25%       -3.000000     -7.000000    -16.000000     -5.000000     -3.000000
# 50%       -1.000000     -1.000000      1.000000      0.000000     -1.000000
# 75%        2.000000      5.000000     16.000000      4.000000      1.000000
# max       32.000000    124.000000    127.000000     72.000000     27.000000
#
#                 Six         Seven         Eight          Rect
# count  11889.000000  11889.000000  11889.000000  11889.000000
# mean      -0.837497     -0.785937     -0.784843      0.504820
# std        5.107624      4.286511      5.020379      0.288646
# min      -24.000000    -38.000000    -31.000000      0.000000
# 25%       -4.000000     -3.000000     -3.000000      0.257143
# 50%       -1.000000     -1.000000     -1.000000      0.507143
# 75%        2.000000      2.000000      2.000000      0.757143
# max       28.000000     38.000000     36.000000      1.000000

# %%
sns.boxplot(data=df_f)

# %%
sns.boxplot(data=df_n)

# %%
df_f.plot()

# %%
df_n.plot()

# %% [markdown]
# ## Filtered data analysis

# %%
sns.heatmap(df_f.corr(), annot=True)

# %%
sns.heatmap(df_n.corr(), annot=True)

# %% [markdown]
# We can clearly see from the corrolations that filtering has helped generate meaningful corrolations between the position of the rectangle paddle, Rect and channel 3. We can also see corrolations between the channels.

# %%
df_f['Rect'].plot()

# %%
df_f['Three'].plot()

# %% [markdown]
# Looking at channel 3, we can see it rise as Rect does.

# %%
df_n['Rect'][2000:4000].plot()

# %%
df_n['Three'][2000:4000].plot()

# %% [markdown]
# ## Filtering the none filtered data.
#
# The filtered signal is a stream of low-pass filtered EMG signals from the eight
#         sensor pods of the Myo armband.
#         Instead of getting the raw EMG signals, we get rectified and smoothed
#         signals, a measure of the amplitude of the EMG (which is useful to have
#         a measure of muscle strength, but are not as useful as a truly raw signal).
#
# ### Rectification

# %%
df_n['Three'][3800:4000].plot()

# %% [markdown]
# As shown above, the EMG signal is made up of both positive and negative components.
# This means the mean of our signal is close to 0.
#
# This can be a problem for analysis, we can see that our filtered data was a high mean.

# %%
df_n.mean()
# Out:
# One     -0.759946
# Two     -0.854656
# Three   -0.420809
# Four    -0.784338
# Five    -0.887543
# Six     -0.837497
# Seven   -0.785937
# Eight   -0.784843
# Rect     0.504820
# dtype: float64

# %%
df_f.mean()
# Out:
# One      29.904864
# Two      38.164521
# Three    70.153076
# Four     39.292561
# Five     42.287554
# Six      41.766810
# Seven    41.842632
# Eight    32.167382
# Rect      0.510040
# dtype: float64

# %%
abs(df_n['Three'][3800:4000]).plot()

# %%
# Rectifying our non filtered data. 
df = abs(df_n)
df['Rect'] = df_n['Rect']
df.plot()

# %%
sns.heatmap(df_n.corr(), annot=True).set_title('Corrolations of raw sEMG data.')
# Out:
# Text(0.5, 1.0, 'Corrolations of raw sEMG data.')

# %%
sns.heatmap(df.corr(), annot=True).set_title('Corrolations of rectified raw sEMG data.')
# Out:
# Text(0.5, 1.0, 'Corrolations of rectified raw sEMG data.')

# %%
sns.heatmap(df_f.corr(), annot=True).set_title('Corrolations of filtered sEMG data.')
# Out:
# Text(0.5, 1.0, 'Corrolations of filtered sEMG data.')

# %%
def plot_rect(df, channel="Three"):
    channel_data = df[channel] / max(df[channel])
    plt.plot(channel_data)
    plt.plot(df['Rect'])
    plt.title('Two or more lines on same plot with suitable legends ')
    # show a legend on the plot
    plt.legend()
    # Display a figure.
    plt.show()
plot_rect(df)
# Out:
# No handles with labels found to put in legend.

# %%
plot_rect(df_f)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# We can see our signal is getting closer to being useful, but we can see our readings hit 0 frequently.

# %%
df['Three'].hist()

# %%
df_f['Three'].hist()

# %%
plt.plot(df['Rect'][0:1400])

# %%
plt.plot(df_f['Rect'])

# %% [markdown]
# We can also see that for the same index range we have much less raw data than filtered data, but why is this?
# To get around this, lets start logging time.

# %%
df.head(10)
# Out:
#    One  Two  Three  Four  Five  Six  Seven  Eight      Rect
# 0  4.0  5.0   31.0   8.0   4.0  3.0    1.0    3.0  0.514286
# 1  4.0  4.0    9.0   4.0   1.0  0.0    0.0    3.0  0.514286
# 2  0.0  9.0    5.0   2.0   1.0  1.0    0.0    0.0  0.514286
# 3  0.0  2.0   15.0   1.0   0.0  0.0    1.0    2.0  0.514286
# 4  3.0  6.0    9.0   2.0   0.0  0.0    2.0    0.0  0.514286
# 5  3.0  7.0    5.0   2.0   4.0  4.0    2.0    3.0  0.514286
# 6  0.0  1.0    6.0   7.0   3.0  4.0    2.0    1.0  0.514286
# 7  2.0  6.0   16.0   4.0   1.0  0.0    0.0    2.0  0.514286
# 8  1.0  6.0    4.0   1.0   3.0  4.0    0.0    1.0  0.514286
# 9  2.0  0.0    9.0   0.0   2.0  2.0    0.0    2.0  0.521429

# %% [markdown]
# In the above 9 rows from our non filtered data, we have multiple readings all for the same rect.
# Compared to below, where in the filtered data we see only one reading per rect value.

# %%
df_f.head(10)
# Out:
#      One    Two  Three  Four   Five   Six  Seven  Eight      Rect
# 0   92.0   69.0   71.0  56.0  175.0  53.0   37.0   50.0  0.542857
# 1  103.0   78.0   73.0  60.0  199.0  58.0   38.0   55.0  0.557143
# 2  112.0   89.0   76.0  67.0  220.0  63.0   38.0   57.0  0.564286
# 3  117.0   99.0   81.0  69.0  238.0  69.0   35.0   53.0  0.571429
# 4  121.0  108.0   77.0  67.0  259.0  79.0   31.0   51.0  0.578571
# 5  117.0  112.0   76.0  65.0  259.0  78.0   29.0   48.0  0.592857
# 6  123.0  116.0   80.0  69.0  271.0  78.0   31.0   47.0  0.600000
# 7  126.0  116.0   80.0  67.0  275.0  78.0   31.0   45.0  0.607143
# 8  118.0  109.0   76.0  63.0  255.0  73.0   30.0   44.0  0.621429
# 9  106.0   93.0   75.0  59.0  218.0  61.0   34.0   42.0  0.628571

# %% [markdown]
# # Comparing 20 seconds of data.

# %%
df_n = pd.read_csv("20_nonfiltered.csv")
df_n.columns = ['One', 'Two', 'Three', "Four", "Five", "Six", "Seven", "Eight", "Rect", "Time_ns"]

df_f = pd.read_csv("20_filtered.csv")
df_f.columns = ['One', 'Two', 'Three', "Four", "Five", "Six", "Seven", "Eight", "Rect", "Time_ns"]
#df.to_csv("testing_data.csv", index=False)

# %%
df_f.describe()
# Out:
#               One         Two       Three        Four        Five         Six  \
# count  993.000000  993.000000  993.000000  993.000000  993.000000  993.000000
# mean    39.912387   83.342397  329.055388   93.079557   41.908359   54.070493
# std     10.022021   43.812094   80.947775   28.403571    8.518283   11.329961
# min     23.000000   41.000000  154.000000   42.000000   27.000000   24.000000
# 25%     33.000000   59.000000  274.000000   73.000000   36.000000   47.000000
# 50%     38.000000   71.000000  323.000000   88.000000   41.000000   52.000000
# 75%     45.000000   86.000000  376.000000  106.000000   46.000000   60.000000
# max     82.000000  329.000000  665.000000  237.000000   77.000000  124.000000
#
#             Seven       Eight         Rect       Time_ns
# count  993.000000  993.000000   993.000000  9.930000e+02
# mean    72.927492   55.869084   738.459215  1.004111e+10
# std     16.587949   18.851098   405.744714  5.751547e+09
# min     36.000000   26.000000     0.000000  9.799299e+07
# 25%     63.000000   42.000000   390.000000  5.076981e+09
# 50%     73.000000   50.000000   770.000000  1.003697e+10
# 75%     82.000000   65.000000  1090.000000  1.502442e+10
# max    182.000000  135.000000  1400.000000  1.998782e+10

# %%
df_n.describe()
# Out:
#                One          Two        Three         Four         Five  \
# count  3989.000000  3989.000000  3989.000000  3989.000000  3989.000000
# mean     -0.748057    -0.937578    -0.871396    -0.771121    -0.823264
# std       2.713862     5.679095    18.384974     5.046276     2.741377
# min     -34.000000   -49.000000  -103.000000   -45.000000   -12.000000
# 25%      -2.000000    -4.000000   -11.000000    -3.000000    -3.000000
# 50%      -1.000000    -1.000000     0.000000    -1.000000    -1.000000
# 75%       1.000000     2.000000    11.000000     2.000000     1.000000
# max      11.000000    36.000000    84.000000    32.000000    12.000000
#
#                Six        Seven        Eight         Rect       Time_ns
# count  3989.000000  3989.000000  3989.000000  3989.000000  3.989000e+03
# mean     -0.805465    -0.754074    -0.764853   738.754074  9.994086e+09
# std       3.305987     4.257854     4.185141   404.532962  5.774062e+09
# min     -13.000000   -42.000000   -23.000000     0.000000  3.224328e+07
# 25%      -3.000000    -3.000000    -3.000000   390.000000  5.010607e+09
# 50%      -1.000000    -1.000000    -1.000000   770.000000  9.993528e+09
# 75%       1.000000     2.000000     1.000000  1090.000000  1.498718e+10
# max      12.000000    52.000000    25.000000  1400.000000  1.997698e+10

# %% [markdown]
# ## The data rate.
# Filtered data: 993.000000  20.004196166992188 seconds.
# Non Filtered data: 3989.000000 20.008700609207153 seconds.
#
# Therefore the filtered data was sent at about 50Hz, and the raw data was sent at about 200Hz.

# %%
len(df_f) / 20
# Out:
# 49.65

# %%
len(df_n) / 20
# Out:
# 199.45

# %%
sns.boxplot(data=df_f.drop(['Time_ns','Rect'], 1))

# %%
sns.boxplot(data=df_n.drop(['Time_ns','Rect'], 1))

# %%
df_f.drop(['Time_ns','Rect'], 1).plot()

# %%
df_n.drop(['Time_ns','Rect'], 1).plot()

# %% [markdown]
# # Investigating the data rate.

# %%
rate_f = df_f['Time_ns'].diff()
rate_f.plot()

# %%
1/ rate_f.mean()
# Out:
# 4.987475161271374e-08

# %%
rate_n = df_n['Time_ns'].diff()
rate_n.plot()

# %% [markdown]
# # Non Filtered raw mode
#
# 3993 samples collected in 20.016239881515503 ~ 196.5Hz.

# %%
df_nr = pd.read_csv("20_0x03_raw.csv")
df_nr.columns = ['One', 'Two', 'Three', "Four", "Five", "Six", "Seven", "Eight", "Rect", "Time_ns"]
df_nr['Rect'] = df_n['Rect'] / max(df_n['Rect'])

# %%
df_nr.describe()
# Out:
#                One          Two        Three         Four         Five  \
# count  3993.000000  3993.000000  3993.000000  3993.000000  3993.000000
# mean     -0.781117    -1.087153    -0.602304    -0.836965    -0.730278
# std       3.913349     9.263263    34.128179    11.329007     5.012272
# min     -28.000000   -87.000000  -128.000000  -123.000000   -38.000000
# 25%      -3.000000    -6.000000   -13.000000    -5.000000    -4.000000
# 50%      -1.000000    -1.000000     0.000000     0.000000    -1.000000
# 75%       1.000000     4.000000    15.000000     4.000000     2.000000
# max      29.000000    65.000000   127.000000    74.000000    34.000000
#
#                Six        Seven        Eight         Rect       Time_ns
# count  3993.000000  3993.000000  3993.000000  3989.000000  3.993000e+03
# mean     -0.790383    -0.797395    -0.882294     0.527681  1.000517e+10
# std       4.191184     5.214706     7.485167     0.288952  5.779633e+09
# min     -24.000000   -29.000000   -50.000000     0.000000  1.652921e+07
# 25%      -3.000000    -4.000000    -4.000000     0.278571  5.005853e+09
# 50%      -1.000000    -1.000000    -1.000000     0.550000  1.000624e+10
# 75%       2.000000     2.000000     1.000000     0.778571  1.500597e+10
# max      22.000000    27.000000    57.000000     1.000000  1.999997e+10

# %% [markdown]
# Given the -128 to 127 range, we can defenitely see the 8 bit signed representation.

# %%
df_nr.drop(['Time_ns','Rect'], 1).plot()

# %%
# Rectifying our non filtered data. 
df = abs(df_nr)
df['Rect'] = df_nr['Rect']
df.drop('Time_ns',1).plot()

# %%
sns.heatmap(df.corr(), annot=True).set_title('Corrolations of non filtered sEMG data.')
# Out:
# Text(0.5, 1.0, 'Corrolations of non filtered sEMG data.')

# %%
def plot_rect(dff, channel="Three", rec=True):
    channel_data = dff[channel] / max(dff[channel])
    if (rec):
        channel_data = abs(channel_data)
    plt.plot(channel_data)
    plt.plot(dff['Rect'] / max(dff['Rect']))
    plt.title('Min Max scaled channel vs Rect')
    # Display a figure.
    plt.show()
plot_rect(abs(df_nr))

# %%
plot_rect(df_n)

# %%
plot_rect(df_f)

# %%
plot_rect(df_nr)

# %%
df['Three'].hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-198d89b53724> in <module>
# ----> 1 df['Three'].hist()
#
# NameError: name 'df' is not defined
